# %% [markdown]
# <a href="https://colab.research.google.com/github/Serge3leo/temp-cola/blob/main/issues/31409/f2py_bug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    # %load_ext fortranmagic
except ModuleNotFoundError as err:
    # Automatic install required packages for know environments
    if "codespace" in str(get_ipython().config):
        # For GitHub Codespace install GNU Fortran, LAPACK, BLAS and pkg-config
        # !conda install -y -q -c conda-forge fortran-compiler lapack blas pkgconfig
        # %pip install -q -U fortran-magic --pre
        # TODO: remove pre-release version by release
        print("Warning: you may need to restart and execute all again")
        # %load_ext fortranmagic
    elif "google.colab" in str(get_ipython().config):
        # Google Colab have preinstalled GNU Fortran, LAPACK, BLAS and pkg-config
        # %pip install -q -U fortran-magic --pre
        # TODO: remove pre-release version by release
        # %load_ext fortranmagic
    else:
        raise AssertionError("Autoinstall") from err
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 34.0 MB/s eta 0:00:00

# %%
additional_options = "--extra '--unknown-option'"

# %%
# %%fortran -v {additional_options}
# subroutine foo
# end subroutine
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_13487/73077199.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('fortran', '-v {additional_options}', 'subroutine foo\nend subroutine\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     221     if line and not cell:
#     222       cell = ' '
# --> 223     return super().run_cell_magic(magic_name, line, cell)
#     224
#     225
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-122> in fortran(self, line, cell)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/fortranmagic.py in fortran(self, line, cell)
#     414
#     415             self._code_cache[key] = module_name
# --> 416             module = _imp_load_dynamic(module_name, module_path)
#     417         self._import_all(module, verbosity=args.verbosity, code=code)
#     418
#
# /usr/local/lib/python3.12/dist-packages/fortranmagic.py in _imp_load_dynamic(name, path)
#      35     loader = importlib.machinery.ExtensionFileLoader(name, path)
#      36     spec = importlib.machinery.ModuleSpec(name=name, loader=loader, origin=path)
# ---> 37     module = importlib.util.module_from_spec(spec)
#      38     loader.exec_module(module)
#      39     return module
#
# /usr/lib/python3.12/importlib/_bootstrap.py in module_from_spec(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in create_module(self, spec)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ImportError: /root/.cache/ipython/fortranmagic/0063e93b/_fortran_magic_c2a8dbc432e36e45defebee873e15427.cpython-312-x86_64-linux-gnu.so: cannot open shared object file: No such file or directory
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
